# %% [markdown]
# <a href="https://colab.research.google.com/github/suvanbalu/Capstone-Data-mining-/blob/main/Capstone1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
data = pd.read_csv("/content/catathon/CAT_Training_Dataset_V3 File.csv")
for (candidate), group in data.groupby(['candidate']):
     group.to_csv(f'{candidate}.csv', index=False)
# Out:
# /usr/local/lib/python3.7/dist-packages/IPython/core/interactiveshell.py:2718: DtypeWarning: Columns (2) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
import pandas as pd
import os
import glob
path = os.getcwd()
csv_files = glob.glob(os.path.join(path, "*.csv"))
for f in csv_files:
    df = pd.read_csv(f)
    for (event,candidate), group in data.groupby(['event','candidate']):
     group.to_csv(f'{candidate}{event}.csv', index=False)

# %%
candidate=input("Enter the candiddate name:")
path="/content/"+candidate+".csv"
import pandas as pd
df = pd.read_csv (path)
df.head
eventList=df.event.unique()
print("\nNumber of events in this candidate:",len(eventList))
for flag in eventList:
  print('\n',flag)
  path1="/content/"+candidate+flag+".csv"
  df1=pd.read_csv(path1)
  c=df1["units"]
  maxValue=c.max()
  thr=maxValue+5000
  print("The Threshold Value is",thr,'\n')
  import matplotlib.pyplot as plt
  import csv
  if df1.shape[0]<3:
    print("Model can't be executed")
  else:
    x = []
    y = []
    X = []
    with open(path1,'r') as csvfile:
        lines = csv.reader(csvfile, delimiter=',')
        for row in lines:
            if row[3]!="units":
                 X.append([float(row[3])])
                 x.append(float(row[3]))
                 y.append(int(row[2]))
    from sklearn.metrics import mean_absolute_error
    from sklearn.metrics import accuracy_score
    from sklearn.model_selection import train_test_split

    x_train , x_val , y_train , y_val = train_test_split(X,y)
 

    plt.plot(x, y, color = 'b', linestyle = 'dashed',marker = 'o')
    plt.xticks(rotation = 25)
    plt.xlabel('units')
    plt.ylabel('date')
    plt.grid()
    plt.show()
    import numpy as np
    from sklearn.linear_model import LinearRegression
    new_model= LinearRegression()
    new_model.fit(X,y)
    preds=new_model.predict([[thr]])
    print(int((preds)/1440),"days from the date of reference")
    new_model.fit(x_train,y_train)
    preds=new_model.predict(x_val)
    mae=mean_absolute_error(y_val,preds)
    print("Mean Absolute Error",round((mae)/1440,2),"days")
# Out:
# Enter the candiddate name:ABCDE00543
#
# Number of events in this candidate: 33
#
#  Component13_SensorB_Low
# The Threshold Value is 17546.0
# 23 days from the date of reference
# Mean Absolute Error 0.56 days
#
#  Component14_discreteSensorD_Low
# The Threshold Value is 5254.0
# 20 days from the date of reference
# Mean Absolute Error 0.0 days
#
#  Component8_SensorB_Low
# The Threshold Value is 18498.0
# 23 days from the date of reference
# Mean Absolute Error 0.05 days
#
#  Component37_deltaSensorB_High
# The Threshold Value is 6577.0
# 20 days from the date of reference
# Mean Absolute Error 0.0 days
#
#  Component1_SensorJ_exceededLimit
# The Threshold Value is 18665.0
# 23 days from the date of reference
# Mean Absolute Error 0.25 days
#
#  Component1_SensorG_Limit
# The Threshold Value is 5492.0
# 20 days from the date of reference
# Mean Absolute Error 0.0 days
#
#  Component27_SensorA_High
# The Threshold Value is 5508.0
# 20 days from the date of reference
# Mean Absolute Error 0.0 days
#
#  Component2_discreteSensorH_Up
# The Threshold Value is 18421.0
# 23 days from the date of reference
# Mean Absolute Error 0.15 days
#
#  Component4_SensorB_discreteSensorD_Low
# The Threshold Value is 18537.0
# 23 days from the date of reference
# Mean Absolute Error 2.94 days
#
#  Component12_FluidC_SensorB_Low
# The Threshold Value is 10689.0
#
# Model can't be executed
#
#  Component15_discreteSensorE_Up
# The Threshold Value is 18958.0
# 23 days from the date of reference
# Mean Absolute Error 0.21 days
#
#  Component34_FluidD_discreteSensorC_Low
# The Threshold Value is 8249.0
# 20 days from the date of reference
# Mean Absolute Error 0.02 days
#
#  Component25_discreteaSensorE_Limit
# The Threshold Value is 18498.0
# 23 days from the date of reference
# Mean Absolute Error 0.18 days
#
#  Component16_FluidB_SensorA_High
# The Threshold Value is 18868.0
# 23 days from the date of reference
# Mean Absolute Error 0.19 days
#
#  Component23_FluidB_SensorA_High
# The Threshold Value is 18993.0
# 23 days from the date of reference
# Mean Absolute Error 0.1 days
#
#  A_Component10_FluidB_SensorA_High
# The Threshold Value is 14769.0
# 22 days from the date of reference
# Mean Absolute Error 0.92 days
#
#  B_Component10_FluidB_SensorA_High
# The Threshold Value is 18177.0
# 23 days from the date of reference
# Mean Absolute Error 0.38 days
#
#  Component17_SensorB_discreteSensorD_Low
# The Threshold Value is 7022.0
#
# Model can't be executed
#
#  Component40_SensorG_High
# The Threshold Value is 8849.0
#
# Model can't be executed
#
#  Component5_SensorB_discreteSensorD_Low
# The Threshold Value is 18498.0
# 23 days from the date of reference
# Mean Absolute Error 0.07 days
#
#  Component33_discreteSensorE_On
# The Threshold Value is 13184.0
#
# Model can't be executed
#
#  Component1_SensorJ_High
# The Threshold Value is 14034.0
#
# Model can't be executed
#
#  Secondary_LocA_Component26_SensorA_High
# The Threshold Value is 16979.0
# 25 days from the date of reference
# Mean Absolute Error 0.1 days
#
#  LocA_Component26_SensorA_High
# The Threshold Value is 16979.0
# 25 days from the date of reference
# Mean Absolute Error 0.2 days
#
#  Component36_deltaSensorB_High
# The Threshold Value is 17420.0
# 22 days from the date of reference
# Mean Absolute Error 0.01 days
#
#  Component35_deltaSensorB_High
# The Threshold Value is 17420.0
# 22 days from the date of reference
# Mean Absolute Error 0.0 days
#
#  Component29_deltaSensorG_High
# The Threshold Value is 18498.0
#
# Model can't be executed
#
#  Secondary_Component32_Fluid_SensorA_High
# The Threshold Value is 17661.0
#
# Model can't be executed
#
#  Component32_FluidA_SensorA_High
# The Threshold Value is 17661.0
#
# Model can't be executed
#
#  Component34_Sensor_High
# The Threshold Value is 17661.0
#
# Model can't be executed
#
#  Component19_FluidE_SensorA_High
# The Threshold Value is 17661.0
#
# Model can't be executed
#
#  Component1_SensorG_High
# The Threshold Value is 18370.0
#
# Model can't be executed
#
#  Component7_deltaSensorB_High
# The Threshold Value is 18886.0
# 22 days from the date of reference
# Mean Absolute Error 0.0 days
